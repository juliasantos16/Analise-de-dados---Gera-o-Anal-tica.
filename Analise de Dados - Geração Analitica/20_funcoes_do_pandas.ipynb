# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('campeonato-brasileiro-full.csv')

# %%
df
# Out:
#         ID  rodata        data   hora       mandante     visitante  \
# 0        1       1  29/03/2003  16:00        Guarani         Vasco
# 1        2       1  29/03/2003  16:00   Athletico-PR        Gremio
# 2        3       1  30/03/2003  16:00       Flamengo      Coritiba
# 3        4       1  30/03/2003  16:00          Goias      Paysandu
# 4        5       1  30/03/2003  16:00  Internacional   Ponte Preta
# ...    ...     ...         ...    ...            ...           ...
# 8400  8401      38  06/12/2023  21:32          Bahia   Atletico-MG
# 8401  8402      38  06/12/2023  21:32         Cuiaba  Athletico-PR
# 8402  8403      38  06/12/2023  21:32         Santos     Fortaleza
# 8403  8404      38  06/12/2023  21:32      Sao Paulo      Flamengo
# 8404  8405      38  06/12/2023  21:32          Vasco    Bragantino
#
#      formacao_mandante formacao_visitante        tecnico_mandante  \
# 0                  NaN                NaN                     NaN
# 1                  NaN                NaN                     NaN
# 2                  NaN                NaN                     NaN
# 3                  NaN                NaN                     NaN
# 4                  NaN                NaN                     NaN
# ...                ...                ...                     ...
# 8400           3-4-2-1              4-4-2                 R. Ceni
# 8401             5-3-2              3-4-3  A. Cardoso de Oliveira
# 8402           3-4-1-2            4-2-3-1            M. Fernandes
# 8403           4-2-3-1            4-2-3-1     D. Silvestre Júnior
# 8404             4-4-2              4-3-3                 R. Díaz
#
#       tecnico_visitante      vencedor                      arena  \
# 0                   NaN       Guarani             Brinco de Ouro
# 1                   NaN  Athletico-PR           Arena da Baixada
# 2                   NaN             -                   Maracanã
# 3                   NaN             -              Serra Dourada
# 4                   NaN             -                  Beira Rio
# ...                 ...           ...                        ...
# 8400         L. Scolari         Bahia  Itaipava Arena Fonte Nova
# 8401        W. Carvalho        Cuiaba             Arena Pantanal
# 8402         J. Vojvoda     Fortaleza    Estádio Urbano Caldeira
# 8403          A. Bacchi     Sao Paulo                    Morumbi
# 8404  P. Faria Caixinha         Vasco       Estádio São Januário
#
#       mandante_Placar  visitante_Placar mandante_Estado visitante_Estado
# 0                   4                 2              SP               RJ
# 1                   2                 0              PR               RS
# 2                   1                 1              RJ               PR
# 3                   2                 2              GO               PA
# 4                   1                 1              RS               SP
# ...               ...               ...             ...              ...
# 8400                4                 1              BA               MG
# 8401                3                 0              MT               PR
# 8402                1                 2              SP               CE
# 8403                1                 0              SP               RJ
# 8404                2                 1              RJ               SP
#
# [8405 rows x 16 columns]

# %%
df.head(5)
# Out:
#    ID  rodata        data   hora       mandante    visitante  \
# 0   1       1  29/03/2003  16:00        Guarani        Vasco
# 1   2       1  29/03/2003  16:00   Athletico-PR       Gremio
# 2   3       1  30/03/2003  16:00       Flamengo     Coritiba
# 3   4       1  30/03/2003  16:00          Goias     Paysandu
# 4   5       1  30/03/2003  16:00  Internacional  Ponte Preta
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# 2               NaN                NaN              NaN               NaN
# 3               NaN                NaN              NaN               NaN
# 4               NaN                NaN              NaN               NaN
#
#        vencedor              arena  mandante_Placar  visitante_Placar  \
# 0       Guarani     Brinco de Ouro                4                 2
# 1  Athletico-PR   Arena da Baixada                2                 0
# 2             -           Maracanã                1                 1
# 3             -      Serra Dourada                2                 2
# 4             -          Beira Rio                1                 1
#
#   mandante_Estado visitante_Estado
# 0              SP               RJ
# 1              PR               RS
# 2              RJ               PR
# 3              GO               PA
# 4              RS               SP

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8405 entries, 0 to 8404
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8405 non-null   int64
#  1   rodata              8405 non-null   int64
#  2   data                8405 non-null   object
#  3   hora                8405 non-null   object
#  4   mandante            8405 non-null   object
#  5   visitante           8405 non-null   object
#  6   formacao_mandante   3431 non-null   object
#  7   formacao_visitante  3431 non-null   object
#  8   tecnico_mandante    3795 non-null   object
#  9   tecnico_visitante   3795 non-null   object
#  10  vencedor            8405 non-null   object
#  11  arena               8405 non-null   object
#  12  mandante_Placar     8405 non-null   int64
#  13  visitante_Placar    8405 non-null   int64
#  14  mandante_Estado     8405 non-null   object
#  15  visitante_Estado    8405 non-null   object
# dtypes: int64(4), object(12)
# memory usage: 1.0+ MB

# %%
# Qual a média de gols do time mandandte?

# %%
df['mandante_Placar'].mean()
# Out:
# 1.5412254610350982

# %%
df['visitante_Placar'].mean()
# Out:
# 1.0270077334919692

# %%
df['Total de Gols']= df['mandante_Placar']+ df['visitante_Placar']

# %%
df.head()
# Out:
#    ID  rodata        data   hora       mandante    visitante  \
# 0   1       1  29/03/2003  16:00        Guarani        Vasco
# 1   2       1  29/03/2003  16:00   Athletico-PR       Gremio
# 2   3       1  30/03/2003  16:00       Flamengo     Coritiba
# 3   4       1  30/03/2003  16:00          Goias     Paysandu
# 4   5       1  30/03/2003  16:00  Internacional  Ponte Preta
#
#   formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 0               NaN                NaN              NaN               NaN
# 1               NaN                NaN              NaN               NaN
# 2               NaN                NaN              NaN               NaN
# 3               NaN                NaN              NaN               NaN
# 4               NaN                NaN              NaN               NaN
#
#        vencedor              arena  mandante_Placar  visitante_Placar  \
# 0       Guarani     Brinco de Ouro                4                 2
# 1  Athletico-PR   Arena da Baixada                2                 0
# 2             -           Maracanã                1                 1
# 3             -      Serra Dourada                2                 2
# 4             -          Beira Rio                1                 1
#
#   mandante_Estado visitante_Estado  Total de Gols
# 0              SP               RJ              6
# 1              PR               RS              2
# 2              RJ               PR              2
# 3              GO               PA              4
# 4              RS               SP              2

# %%
df['Total de Gols'].mean()
# Out:
# 2.568233194527067

# %%
# Qual o time que mais venceu?

# %%
df['vencedor'].value_counts()
# Out:
# vencedor
# -                  2221
# Sao Paulo           365
# Flamengo            354
# Santos              340
# Internacional       339
# Palmeiras           329
# Atletico-MG         327
# Corinthians         326
# Fluminense          322
# Gremio              316
# Athletico-PR        309
# Cruzeiro            304
# Botafogo-RJ         247
# Goias               209
# Vasco               208
# Coritiba            189
# Figueirense         142
# Sport               131
# Bahia               127
# Vitoria             123
# Ponte Preta         114
# Fortaleza           108
# Juventude            85
# Parana               83
# Atletico-GO          72
# Ceara                72
# Chapecoense          70
# Avai                 66
# Sao Caetano          65
# America-MG           58
# Bragantino           55
# Nautico              54
# Criciuma             50
# Paysandu             41
# Guarani              36
# Cuiaba               34
# Portuguesa           31
# Santa Cruz           15
# Barueri              12
# Santo Andre          11
# Brasiliense          10
# Ipatinga              9
# CSA                   8
# Gremio Prudente       7
# Joinville             7
# America-RN            4
# Name: count, dtype: int64

# %%
df['venceder'] = df['vencedor'].str.upper()

# %%
df['vencedor']
# Out:
# 0            Guarani
# 1       Athletico-PR
# 2                  -
# 3                  -
# 4                  -
#             ...
# 8400           Bahia
# 8401          Cuiaba
# 8402       Fortaleza
# 8403       Sao Paulo
# 8404           Vasco
# Name: vencedor, Length: 8405, dtype: object

# %%
df['vencedor'].value_counts()
# Out:
# vencedor
# -                  2221
# Sao Paulo           365
# Flamengo            354
# Santos              340
# Internacional       339
# Palmeiras           329
# Atletico-MG         327
# Corinthians         326
# Fluminense          322
# Gremio              316
# Athletico-PR        309
# Cruzeiro            304
# Botafogo-RJ         247
# Goias               209
# Vasco               208
# Coritiba            189
# Figueirense         142
# Sport               131
# Bahia               127
# Vitoria             123
# Ponte Preta         114
# Fortaleza           108
# Juventude            85
# Parana               83
# Atletico-GO          72
# Ceara                72
# Chapecoense          70
# Avai                 66
# Sao Caetano          65
# America-MG           58
# Bragantino           55
# Nautico              54
# Criciuma             50
# Paysandu             41
# Guarani              36
# Cuiaba               34
# Portuguesa           31
# Santa Cruz           15
# Barueri              12
# Santo Andre          11
# Brasiliense          10
# Ipatinga              9
# CSA                   8
# Gremio Prudente       7
# Joinville             7
# America-RN            4
# Name: count, dtype: int64

# %%
# Qual estado com maior números de vitórias?

# %%
df['mandante_Estado'].value_counts()
# Out:
# mandante_Estado
# SP    2097
# RJ    1480
# RS     902
# MG     875
# PR     809
# SC     587
# GO     428
# BA     411
# PE     342
# CE     291
# PA      67
# MT      57
# DF      21
# RN      19
# AL      19
# Name: count, dtype: int64

# %%
# SORT_VALUES

# %%
df.sort_values(by='mandante_Placar',ascending=False)
# Out:
#         ID  rodata        data   hora       mandante    visitante  \
# 8300  8302      28  22/10/2023  16:00  Internacional       Santos
# 1258  1263      15  27/07/2005  21:45   Athletico-PR        Vasco
# 66      66       6  27/04/2003  16:00          Goias    Juventude
# 936    937      33  28/09/2004  20:30      Sao Paulo     Paysandu
# 1002  1003      38  27/10/2004  20:30     Fluminense    Juventude
# ...    ...     ...         ...    ...            ...          ...
# 5770  5772       3  28/05/2017  16:00    Atletico-GO  Corinthians
# 5771  5771       3  28/05/2017  16:02         Santos     Cruzeiro
# 1386  1398      27  22/09/2005  20:30      Juventude     Coritiba
# 5779  5779       4  04/06/2017  11:01       Flamengo  Botafogo-RJ
# 5709  5710      35  16/11/2016  21:45          Sport     Cruzeiro
#
#      formacao_mandante formacao_visitante     tecnico_mandante  \
# 8300           4-2-3-1            3-4-1-2            E. Coudet
# 1258               NaN                NaN                  NaN
# 66                 NaN                NaN                  NaN
# 936                NaN                NaN                  NaN
# 1002               NaN                NaN                  NaN
# ...                ...                ...                  ...
# 5770           4-2-3-1            4-1-4-1      M. Ribeiro Cabo
# 5771           4-2-3-1            4-3-2-1  D. Silvestre Júnior
# 1386               NaN                NaN                  NaN
# 5779           4-2-3-1            4-1-4-1         J. Mannarino
# 5709           4-2-3-1            4-2-3-1     D. Pollo Barioni
#
#          tecnico_visitante       vencedor  \
# 8300          M. Fernandes  Internacional
# 1258                   NaN   Athletico-PR
# 66                     NaN          Goias
# 936                    NaN      Sao Paulo
# 1002                   NaN     Fluminense
# ...                    ...            ...
# 5770            F. Carille    Corinthians
# 5771  L. Venker de Menezes       Cruzeiro
# 1386                   NaN              -
# 5779    J. Ribeiro Ventura              -
# 5709  L. Venker de Menezes       Cruzeiro
#
#                                                   arena  mandante_Placar  \
# 8300                                  Estádio Beira-Rio                7
# 1258                                   Arena da Baixada                7
# 66                                        Serra Dourada                7
# 936                                             Morumbi                7
# 1002                                Raulino de Oliveira                7
# ...                                                 ...              ...
# 5770  Estádio do Governo do Estado de Goiás (Serra D...                0
# 5771                            Estádio Urbano Caldeira                0
# 1386                                     Alfredo Jaconi                0
# 5779      Estádio Municipal General Raulino de Oliveira                0
# 5709                          Adelmar da Costa Carvalho                0
#
#       visitante_Placar mandante_Estado visitante_Estado  Total de Gols  \
# 8300                 1              RS               SP              8
# 1258                 2              PR               RJ              9
# 66                   0              GO               RS              7
# 936                  0              SP               PA              7
# 1002                 1              RJ               RS              8
# ...                ...             ...              ...            ...
# 5770                 1              GO               SP              1
# 5771                 1              SP               MG              1
# 1386                 0              RS               PR              0
# 5779                 0              RJ               RJ              0
# 5709                 1              PE               MG              1
#
#            venceder
# 8300  INTERNACIONAL
# 1258   ATHLETICO-PR
# 66            GOIAS
# 936       SAO PAULO
# 1002     FLUMINENSE
# ...             ...
# 5770    CORINTHIANS
# 5771       CRUZEIRO
# 1386              -
# 5779              -
# 5709       CRUZEIRO
#
# [8405 rows x 18 columns]

# %%
# Unique

# %%
df['vencedor'].unique()
# Out:
# array(['Guarani', 'Athletico-PR', '-', 'Criciuma', 'Atletico-MG',
#        'Internacional', 'Gremio', 'Flamengo', 'Vitoria', 'Ponte Preta',
#        'Parana', 'Sao Caetano', 'Cruzeiro', 'Vasco', 'Paysandu', 'Santos',
#        'Corinthians', 'Juventude', 'Bahia', 'Fluminense', 'Sao Paulo',
#        'Fortaleza', 'Coritiba', 'Goias', 'Figueirense', 'Palmeiras',
#        'Botafogo-RJ', 'Brasiliense', 'Santa Cruz', 'Sport', 'America-RN',
#        'Nautico', 'Ipatinga', 'Portuguesa', 'Santo Andre', 'Barueri',
#        'Avai', 'Ceara', 'Gremio Prudente', 'Atletico-GO', 'America-MG',
#        'Chapecoense', 'Joinville', 'CSA', 'Bragantino', 'Cuiaba'],
#       dtype=object)

# %%
# nunique

# %%
df['mandante_Placar'].nunique()
# Out:
# 8

# %%
# Qual foi a maior goleada de todos os tempos?

# %%
df[df['mandante_Placar'] == df['mandante_Placar'].max()]
# Out:
#         ID  rodata        data   hora       mandante  visitante  \
# 66      66       6  27/04/2003  16:00          Goias  Juventude
# 616    618       6  16/05/2004  16:00       Criciuma      Goias
# 936    937      33  28/09/2004  20:30      Sao Paulo   Paysandu
# 1002  1003      38  27/10/2004  20:30     Fluminense  Juventude
# 1258  1263      15  27/07/2005  21:45   Athletico-PR      Vasco
# 1504  1505      37  06/11/2005  16:00    Corinthians     Santos
# 8300  8302      28  22/10/2023  16:00  Internacional     Santos
#
#      formacao_mandante formacao_visitante tecnico_mandante tecnico_visitante  \
# 66                 NaN                NaN              NaN               NaN
# 616                NaN                NaN              NaN               NaN
# 936                NaN                NaN              NaN               NaN
# 1002               NaN                NaN              NaN               NaN
# 1258               NaN                NaN              NaN               NaN
# 1504               NaN                NaN              NaN               NaN
# 8300           4-2-3-1            3-4-1-2        E. Coudet      M. Fernandes
#
#            vencedor                  arena  mandante_Placar  visitante_Placar  \
# 66            Goias          Serra Dourada                7                 0
# 616        Criciuma        Heriberto Hulse                7                 2
# 936       Sao Paulo                Morumbi                7                 0
# 1002     Fluminense    Raulino de Oliveira                7                 1
# 1258   Athletico-PR       Arena da Baixada                7                 2
# 1504    Corinthians               Pacaembu                7                 1
# 8300  Internacional      Estádio Beira-Rio                7                 1
#
#      mandante_Estado visitante_Estado  Total de Gols       venceder
# 66                GO               RS              7          GOIAS
# 616               SC               GO              9       CRICIUMA
# 936               SP               PA              7      SAO PAULO
# 1002              RJ               RS              8     FLUMINENSE
# 1258              PR               RJ              9   ATHLETICO-PR
# 1504              SP               SP              8    CORINTHIANS
# 8300              RS               SP              8  INTERNACIONAL
